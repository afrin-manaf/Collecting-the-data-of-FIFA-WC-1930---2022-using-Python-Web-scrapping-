# %%
import pandas as pd

# %%
df_historical_data = pd.read_csv('fifa.csv')
df_fixture = pd.read_csv('fifa2022.csv')

# %%
df_historical_data
# Out:
#            home         score      away  year
# 0       France            4–1    Mexico  year
# 1    Argentina            1–0    France  year
# 2        Chile            3–0    Mexico  year
# 3        Chile            1–0    France  year
# 4    Argentina            6–3    Mexico  year
# ..          ...           ...       ...   ...
# 860     Russia   2–2 (a.e.t.)   Croatia  year
# 861     France            1–0   Belgium  year
# 862    Croatia   2–1 (a.e.t.)   England  year
# 863    Belgium            2–0   England  year
# 864     France            4–2   Croatia  year
#
# [865 rows x 4 columns]

# %%
df_fixture['home'] = df_fixture['home'].str.strip()
df_fixture['away'] = df_fixture['away'].str.strip()

# %%
df_historical_data[df_historical_data['home'].isnull()]
# Out:
# Empty DataFrame
# Columns: [home, score, away, year]
# Index: []

# %%
df_historical_data.drop_duplicates(inplace=True)
df_historical_data.sort_values('year',inplace=True)
df_historical_data
# Out:
#                      home score                  away  year
# 0                 France    4–1                Mexico  year
# 569  Republic of Ireland    1–1              Cameroon  year
# 570              Germany    8–0          Saudi Arabia  year
# 571              Germany    1–1   Republic of Ireland  year
# 572             Cameroon    1–0          Saudi Arabia  year
# ..                    ...   ...                   ...   ...
# 290          Netherlands    3–0                  Iran  year
# 291             Scotland    1–1                  Iran  year
# 292          Netherlands    0–0                  Peru  year
# 294             Scotland    3–2           Netherlands  year
# 864               France    4–2               Croatia  year
#
# [858 rows x 4 columns]

# %%
delete_index = df_historical_data[df_historical_data['home'].str.contains('Sweden') & df_historical_data['away'].str.contains('Austria')].index
df_historical_data.drop(index=delete_index,inplace=True)

# %%
df_historical_data[df_historical_data['home'].str.contains('Sweden') & df_historical_data['away'].str.contains('Austria')].index
# Out:
# Index([], dtype='int64')

# %%
df_historical_data['score']
# Out:
# 0      4–1
# 569    1–1
# 570    8–0
# 571    1–1
# 572    1–0
#       ...
# 290    3–0
# 291    1–1
# 292    0–0
# 294    3–2
# 864    4–2
# Name: score, Length: 857, dtype: object

# %%
df_historical_data['home'] = df_historical_data['home'].str.strip()
df_historical_data['away'] = df_historical_data['away'].str.strip()

# %%
df_historical_data
# Out:
#                     home score                 away  year
# 0                 France   4–1               Mexico  year
# 569  Republic of Ireland   1–1             Cameroon  year
# 570              Germany   8–0         Saudi Arabia  year
# 571              Germany   1–1  Republic of Ireland  year
# 572             Cameroon   1–0         Saudi Arabia  year
# ..                   ...   ...                  ...   ...
# 290          Netherlands   3–0                 Iran  year
# 291             Scotland   1–1                 Iran  year
# 292          Netherlands   0–0                 Peru  year
# 294             Scotland   3–2          Netherlands  year
# 864               France   4–2              Croatia  year
#
# [857 rows x 4 columns]

# %%
df_historical_data[['HomeGoals', 'AwayGoals']] = df_historical_data['score'].str.split('–', expand=True)

# %%
df_historical_data.drop('score', axis=1, inplace=True)

# %%
df_historical_data
# Out:
#                     home                 away  year HomeGoals AwayGoals
# 0                 France               Mexico  year         4         1
# 569  Republic of Ireland             Cameroon  year         1         1
# 570              Germany         Saudi Arabia  year         8         0
# 571              Germany  Republic of Ireland  year         1         1
# 572             Cameroon         Saudi Arabia  year         1         0
# ..                   ...                  ...   ...       ...       ...
# 290          Netherlands                 Iran  year         3         0
# 291             Scotland                 Iran  year         1         1
# 292          Netherlands                 Peru  year         0         0
# 294             Scotland          Netherlands  year         3         2
# 864               France              Croatia  year         4         2
#
# [857 rows x 5 columns]

# %%
df_historical_data.rename(columns={'home': 'HomeTeam','away': 'AwayTeam', 'year': 'Year'}, inplace=True)
df_historical_data = df_historical_data.astype({'HomeGoals': int, 'AwayGoals': int, 'Year':int})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 df_historical_data.rename(columns={'home': 'HomeTeam','away': 'AwayTeam', 'year': 'Year'}, inplace=True)
# ----> 2 df_historical_data = df_historical_data.astype({'HomeGoals': int, 'AwayGoals': int, 'Year':int})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6305, in NDFrame.astype(self, dtype, copy, errors)
#    6303 else:
#    6304     try:
# -> 6305         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6306     except ValueError as ex:
#    6307         ex.args = (
#    6308             f"{ex}: Error while type casting for column '{col_name}'",
#    6309         )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:138, in _astype_nansafe(arr, dtype, copy, skipna)
#     134     raise ValueError(msg)
#     136 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     137     # Explicit copy, or required since NumPy can't view from / to object.
# --> 138     return arr.astype(dtype, copy=True)
#     140 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'year': Error while type casting for column 'Year'

# %%
df_historical_data.dtypes
# Out:
# HomeTeam     object
# AwayTeam     object
# Year         object
# HomeGoals    object
# AwayGoals    object
# dtype: object
